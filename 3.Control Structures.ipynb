# %%
age = int(input("Enter Age: "))
# Out:
# Enter Age:  58

# %%
if(age < 18):
    print("Children and age is", age)
else:
    print("Adult and age is", age)
# Out:
# Children and age is 17

# %%
if(age < 18):
    print("Children and age is", age)
elif(age < 35):
    print("Adult and age is", age)
elif(age < 59):
    print("Citizen and age is", age)
else:
    print("Senior Citizen and age is", age)
# Out:
# Citizen and age is 58
