# %%
from groupAllFunctions import groupAllFunctions

# %%
groupAllFunctions.Elegible()
# Out:
# Your Gender:  male
# Your Age:  25
# ELIGIBLE

# %%
groupAllFunctions.Subfields()
# Out:
# Sub-fields in AI are:
# Machine Learning
# Neural Networks
# Vision
# Robotics
# Speech Processing
# Natural Language Processing

# %%
groupAllFunctions.OddEven()
# Out:
# Enter a number:  37
# 37  is Odd number

# %%
groupAllFunctions.percentage()
# Out:
# Subject1=  89
# Subject2=  91
# Subject3=  95
# Subject4=  85
# Subject5=  90
# Total :  450
# Percentage :  90.0 %

# %%
groupAllFunctions.triangle()
# Out:
# Height:  32
# Breadth:  34
# Area formula: (Height*Breadth)/2
# Area of Triangle:  544.0
# Height1:  2
# Height2:  4
# Breadth:  4
# Perimeter formula: Height1+Height2+Breadth
# Perimeter of Triangle: 10
